# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load and get data

# %%
# url = "https://object.files.data.gouv.fr/meteofrance-drias/SocleM-Climat-2025/CPRCM/METROPOLE/ALPX-3/CNRM-ESM2-1/r1i1p1f2/CNRM-AROME46t1/ssp370/day/tasAdjust/version-hackathon-102025/tasAdjust_FR-Metro_CNRM-ESM2-1_ssp370_r1i1p1f2_CNRM-MF_CNRM-AROME46t1_v1-r1_MF-CDFt-ANASTASIA-SAFRAN-1991-2020_day_20150101-21001231.nc"

# file_path = r"../Data/tasAdjust_FR-Metro_CNRM-ESM2-1_ssp370_r1i1p1f2_CNRM-MF_CNRM-AROME46t1_v1-r1_MF-CDFt-ANASTASIA-SAFRAN-1991-2020_day_20150101-21001231.nc"

# ds = xr.open_dataset(file_path)

# print(ds)


file_path = "../Data/tasAdjust_FR-Metro_CNRM-ESM2-1_ssp370_r1i1p1f2_CNRM-MF_CNRM-AROME46t1_v1-r1_MF-CDFt-ANASTASIA-SAFRAN-1991-2020_day_20150101-21001231.nc"

ds = xr.open_dataset(file_path, chunks={"time": 100})

# %% [markdown]
# #### turn into data array

# %%
print(ds.data_vars)
# Out:
# Data variables:
#     lon_bnds        (y, x, nbounds) float64 613kB dask.array<chunksize=(134, 143, 4), meta=np.ndarray>
#     lat_bnds        (y, x, nbounds) float64 613kB dask.array<chunksize=(134, 143, 4), meta=np.ndarray>
#     LambertParisII  int32 4B ...
#     tasAdjust       (time, y, x) float32 2GB dask.array<chunksize=(100, 134, 143), meta=np.ndarray>
#     time_bnds       (time, bnds) datetime64[ns] 503kB dask.array<chunksize=(100, 2), meta=np.ndarray>

# %%
da = ds["tasAdjust"]

# %%
print(da)
print(type(da))
# Out:
# <xarray.DataArray 'tasAdjust' (time: 31411, y: 134, x: 143)> Size: 2GB
# dask.array<open_dataset-tasAdjust, shape=(31411, 134, 143), dtype=float32, chunksize=(100, 134, 143), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 251kB 2015-01-01T12:00:00 ... 2100-12-31T1...
#   * y        (y) float64 1kB 1.617e+06 1.625e+06 ... 2.673e+06 2.681e+06
#   * x        (x) float64 1kB 6e+04 6.8e+04 7.6e+04 ... 1.188e+06 1.196e+06
#     lon      (y, x) float64 153kB dask.array<chunksize=(134, 143), meta=np.ndarray>
#     lat      (y, x) float64 153kB dask.array<chunksize=(134, 143), meta=np.ndarray>
# Attributes:
#     standard_name:          air_temperature
#     long_name:              Bias Corrected Near-Surface Air Temperature
#     units:                  K
#     grid_mapping:           LambertParisII
#     cell_methods:           time: mean
#     coverage_content_type:  derivedData
#     units_metadata:         temperature: on_scale
# <class 'xarray.core.dataarray.DataArray'>

# %%
print(da.shape)
print(da.dims)
# Out:
# (31411, 134, 143)
# ('time', 'y', 'x')

# %%
da_valid = da.where(~np.isnan(da).all(dim="time"), drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 da_valid = da.where(~np.isnan(da).all(dim="time"), drop=True)
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\common.py:1246, in DataWithCoords.where(self, cond, other, drop)
#    1243     for dim in cond.sizes.keys():
#    1244         indexers[dim] = _get_indexer(dim)
# -> 1246     self = self.isel(**indexers)
#    1247     cond = cond.isel(**indexers)
#    1249 from xarray.computation import ops
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\dataarray.py:1574, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1571 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    1573 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1574     ds = self._to_temp_dataset()._isel_fancy(
#    1575         indexers, drop=drop, missing_dims=missing_dims
#    1576     )
#    1577     return self._from_temp_dataset(ds)
#    1579 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1580 # lists, or zero or one-dimensional np.ndarray's
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\dataset.py:2891, in Dataset._isel_fancy(self, indexers, drop, missing_dims)
#    2887 var_indexers = {
#    2888     k: v for k, v in valid_indexers.items() if k in var.dims
#    2889 }
#    2890 if var_indexers:
# -> 2891     new_var = var.isel(indexers=var_indexers)
#    2892     # drop scalar coordinates
#    2893     # https://github.com/pydata/xarray/issues/6554
#    2894     if name in self.coords and drop and new_var.ndim == 0:
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\variable.py:1130, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1127 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1129 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1130 return self[key]
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\variable.py:817, in Variable.__getitem__(self, key)
#     804 def __getitem__(self, key) -> Self:
#     805     """Return a new Variable object whose contents are consistent with
#     806     getting the provided key from the underlying data.
#     807
#    (...)    815     array `x.values` directly.
#     816     """
# --> 817     dims, indexer, new_order = self._broadcast_indexes(key)
#     818     indexable = as_indexable(self._data)
#     820     data = indexing.apply_indexer(indexable, indexer)
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\variable.py:656, in Variable._broadcast_indexes(self, key)
#     650 if all(
#     651     (isinstance(k, BASIC_INDEXING_TYPES) and not isinstance(k, bool))
#     652     for k in key
#     653 ):
#     654     return self._broadcast_indexes_basic(key)
# --> 656 self._validate_indexers(key)
#     657 # Detect it can be mapped as an outer indexer
#     658 # If all key is unlabeled, or
#     659 # key can be mapped as an OuterIndexer.
#     660 if all(not isinstance(k, Variable) for k in key):
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\variable.py:709, in Variable._validate_indexers(self, key)
#     705     raise IndexError(
#     706         f"{k.ndim}-dimensional boolean indexing is not supported. "
#     707     )
#     708 if is_duck_dask_array(k.data):
# --> 709     raise KeyError(
#     710         "Indexing with a boolean dask array is not allowed. "
#     711         "This will result in a dask array of unknown shape. "
#     712         "Such arrays are unsupported by Xarray."
#     713         "Please compute the indexer first using .compute()"
#     714     )
#     715 if getattr(k, "dims", (dim,)) != (dim,):
#     716     raise IndexError(
#     717         "Boolean indexer should be unlabeled or on the "
#     718         "same dimension to the indexed array. Indexer is "
#     719         f"on {k.dims} but the target dimension is {dim}."
#     720     )
#
# KeyError: 'Indexing with a boolean dask array is not allowed. This will result in a dask array of unknown shape. Such arrays are unsupported by Xarray.Please compute the indexer first using .compute()'

# %% [markdown]
# #### Getting all time series for one lat lon

# %%
lat_target = 45.5
lon_target = 6.2

# %%
point_ts = da.sel(lat=lat_target, lon=lon_target, method="nearest")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 point_ts = da.sel(lat=lat_target, lon=lon_target, method="nearest")
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\dataarray.py:1717, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1601 def sel(
#    1602     self,
#    1603     indexers: Mapping[Any, Any] | None = None,
#    (...)   1607     **indexers_kwargs: Any,
#    1608 ) -> Self:
#    1609     """Return a new DataArray whose data is given by selecting index
#    1610     labels along the specified dimension(s).
#    1611
#    (...)   1715     Dimensions without coordinates: points
#    1716     """
# -> 1717     ds = self._to_temp_dataset().sel(
#    1718         indexers=indexers,
#    1719         drop=drop,
#    1720         method=method,
#    1721         tolerance=tolerance,
#    1722         **indexers_kwargs,
#    1723     )
#    1724     return self._from_temp_dataset(ds)
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\dataset.py:2988, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2920 """Returns a new dataset with each array indexed by tick labels
#    2921 along the specified dimension(s).
#    2922
#    (...)   2985
#    2986 """
#    2987 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2988 query_results = map_index_queries(
#    2989     self, indexers=indexers, method=method, tolerance=tolerance
#    2990 )
#    2992 if drop:
#    2993     no_scalar_variables = {}
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\indexing.py:193, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     190     options = {"method": method, "tolerance": tolerance}
#     192 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "map_index_queries")
# --> 193 grouped_indexers = group_indexers_by_index(obj, indexers, options)
#     195 results = []
#     196 for index, labels in grouped_indexers:
#
# File c:\Users\jules\anaconda3\envs\hackathonweather\Lib\site-packages\xarray\core\indexing.py:152, in group_indexers_by_index(obj, indexers, options)
#     150     grouped_indexers[index_id][key] = label
#     151 elif key in obj.coords:
# --> 152     raise KeyError(f"no index found for coordinate {key!r}")
#     153 elif key not in obj.dims:
#     154     raise KeyError(
#     155         f"{key!r} is not a valid dimension or coordinate for "
#     156         f"{obj.__class__.__name__} with dimensions {obj.dims!r}"
#     157     )
#
# KeyError: "no index found for coordinate 'lat'"

# %%
da_first = da.isel(time=0).compute()

# %%
plt.imshow(da_first, origin='lower')
plt.colorbar(label='Temperature')
plt.show()

# %%
da_rand = da.isel(time=1234).compute()

# %%
plt.imshow(da_rand, origin='lower')
plt.colorbar(label='Temperature', cmap='jet')
plt.show()

# %%
y_idx = 60  # replace with your chosen y index
x_idx = 80  # replace with your chosen x index
# point_ts is a DataArray of shape (time,)
point_ts = da[:, y_idx, x_idx].compute()  # compute loads only this 1D array

# %%
plt.figure(figsize=(12,4))
plt.plot(point_ts.time, point_ts.values)
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.title(f"Temperature time series at y={y_idx}, x={x_idx}")
plt.show()

# %%
lats = ds["lat"].values   # 2D array of latitudes
lons = ds["lon"].values   # 2D array of longitudes

print(lats.shape, lons.shape)  # should match (y, x)
print(lats, lons)              # shows all values
# Out:
# (134, 143) (134, 143)
# [[41.361 41.367 41.373 ... 41.331 41.325 41.318]
#  [41.433 41.439 41.444 ... 41.402 41.396 41.39 ]
#  [41.504 41.51  41.516 ... 41.474 41.468 41.461]
#  ...
#  [50.742 50.749 50.756 ... 50.706 50.699 50.691]
#  [50.814 50.821 50.827 ... 50.778 50.77  50.762]
#  [50.885 50.892 50.899 ... 50.849 50.841 50.834]] [[-4.09690905 -4.00201368 -3.90709972 ...  9.24429703  9.33907509
#    9.43383408]
#  [-4.10470295 -4.00969362 -3.91466594 ...  9.25265789  9.34755039
#    9.44242191]
#  [-4.11251593 -4.01739264 -3.92225051 ...  9.26103973  9.35604572
#    9.45103168]
#  ...
#  [-5.30820227 -5.19564533 -5.0830574  ... 10.54347706 10.65583897
#   10.7681675 ]
#  [-5.31920004 -5.20648289 -5.09373474 ... 10.5552702  10.66779137
#   10.78027821]
#  [-5.33022928 -5.21735191 -5.10444307 ... 10.56709671 10.67977715
#   10.7924242 ]]

# %%
print("Latitude:", lats[y_idx, x_idx])
print("Longitude:", lons[y_idx, x_idx])
# Out:
# Latitude: 45.866
# Longitude: 3.62440896034241

# %% [markdown]
# #### temp a paris

# %%
# Target coordinates Paris
lat_target = 48.8566
lon_target = 2.3522

# Compute distance squared to every grid cell
dist2 = (ds["lat"].values - lat_target)**2 + (ds["lon"].values - lon_target)**2

# Find indices of the minimum distance
y_idx, x_idx = np.unravel_index(np.argmin(dist2), dist2.shape)

print("Nearest grid cell:", y_idx, x_idx)
print("Latitude, Longitude:", ds["lat"].values[y_idx, x_idx], ds["lon"].values[y_idx, x_idx])
# Out:
# Nearest grid cell: 101 68
# Latitude, Longitude: 48.823 2.39095163345337

# %%
# Extract time series for that grid cell
point_ts = da[:, y_idx, x_idx].compute()

# Plot
plt.figure(figsize=(12,4))
plt.plot(point_ts.time, point_ts.values)
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.title(f"Temperature time series at lat={ds['lat'].values[y_idx, x_idx]:.3f}, lon={ds['lon'].values[y_idx, x_idx]:.3f}")
plt.show()
